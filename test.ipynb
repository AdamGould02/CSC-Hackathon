# %%
from nba_api.stats.endpoints import leaguegamelog


current = leaguegamelog.LeagueGameLog(season="2022-23", player_or_team_abbreviation="P", direction="DESC")

current.get_data_frames()[0]
# Out:
#      SEASON_ID  PLAYER_ID            PLAYER_NAME     TEAM_ID  \
# 0        22022     203488           Mike Muscala  1610612760
# 1        22022    1626157     Karl-Anthony Towns  1610612750
# 2        22022    1626224             Cedi Osman  1610612739
# 3        22022    1627747           Caris LeVert  1610612739
# 4        22022    1627752         Taurean Prince  1610612750
# ...        ...        ...                    ...         ...
# 4237     22022    1629308  Juan Toscano-Anderson  1610612747
# 4238     22022    1630228       Jonathan Kuminga  1610612744
# 4239     22022       2544           LeBron James  1610612747
# 4240     22022    1627759           Jaylen Brown  1610612738
# 4241     22022    1628978       Donte DiVincenzo  1610612744
#
#      TEAM_ABBREVIATION               TEAM_NAME     GAME_ID   GAME_DATE  \
# 0                  OKC   Oklahoma City Thunder  0022200192  2022-11-13
# 1                  MIN  Minnesota Timberwolves  0022200193  2022-11-13
# ...
